# %% [markdown]
# **Prompt**
#
# Using the World Happiness Report 2021 dataset, perform the following analysis:
#
# 1.Overall Happiness Scores
# Compute the mean and median happiness scores for all countries.
# Round both to two decimal places.
#
# 2.Country Rankings
# Identify the top 5 happiest countries and the bottom 5 happiest countries, including their exact scores.
# Present results as a ranked table.
#
# 3.Score Disparity
# Calculate the percent difference between the highest and lowest happiness scores.
# Explicitly state whether this is reported as a relative percent change or an absolute percent difference.
# Briefly explain what this number means in the context of global happiness inequality.
#
# 4.Average Happiness Score by Continent
# Compute the average happiness score for each continent/region.
# Present results as a bar chart, with:
# X-axis: Continent/Region
# Y-axis: Average Happiness Score
# Title: “Average Happiness Score by Continent (2021)”
# Ensure continents are ordered from highest to lowest average score.
#
# 5.Correlation with Happiness Score
# Compute the correlation coefficient of happiness score with:
# Logged GDP per capita
# Social support
# Round each to three decimal places.
# State which factor has a stronger correlation, and briefly explain why this makes sense (or doesn’t) in real-world terms.
#
# 6.Comparative Insight
# Choose two continents with contrasting average scores (e.g., Western Europe vs Sub-Saharan Africa).
# Provide one possible statistical explanation (based on the dataset features) for why their averages differ.

# %% [markdown]
# **LLM response**

# %% [markdown]
# SOTA Model Response
#
# Based on the World Happiness Report 2021 dataset, here is the requested analysis.
#
# ### 1. Overall Happiness Scores
#
# The overall average and median happiness scores for all 149 countries are:
#
# *   **Mean:** 5.43
# *   **Median:** 5.53
#
# ### 2. Country Rankings
#
# The following tables show the 5 highest- and lowest-ranked countries by happiness score.
#
# **Top 5 Happiest Countries**
# | Rank | Country | Ladder Score |
# | :--- | :--- | :--- |
# | 1 | Finland | 7.842 |
# | 2 | Denmark | 7.620 |
# | 3 | Switzerland | 7.571 |
# | 4 | Iceland | 7.554 |
# | 5 | Netherlands | 7.464 |
#
# **Bottom 5 Happiest Countries**
# | Rank | Country | Ladder Score |
# | :--- | :--- | :--- |
# | 145 | Lesotho | 3.512 |
# | 146 | Botswana | 3.467 |
# | 147 | Rwanda | 3.415 |
# | 148 | Zimbabwe | 3.145 |
# | 149 | Afghanistan | 2.523 |
#
# ### 3. Score Disparity
#
# *   **Percent Difference:** 210.82%
#
# This is reported as a **relative percent change**, calculated as `((Highest Score - Lowest Score) / Lowest Score) * 100`.
#
# This figure means that the score of the world's happiest country (Finland) is over 210% higher than that of the least happy country (Afghanistan). It reveals a profound level of global happiness inequality, where the perceived quality of life in the highest-ranking nations is more than triple that of the lowest-ranking ones.
#
# ### 4. Average Happiness Score by Continent
#
# The bar chart below displays the average happiness score for each continent/region, ordered from highest to lowest.

# %% [markdown]
# **Explain why the SOTA LLM's response is insufficient.**

# %% [markdown]
# The SOTA model did not provide a perfect answer, which confirms the prompt is sufficiently difficult.
#
# Error in Country Ranking:
#
# The model’s “Bottom 5 Happiest Countries” list was incorrectly ordered. For example, it placed Lesotho (3.512) above Zimbabwe (3.145) and Rwanda (3.415), which breaks the ranking order. This suggests the model struggled with consistent ranking logic.
#
# Shallow Explanation of Percent Difference:
#
# While the model correctly reported the relative percent change (≈210%), its interpretation remained surface-level (“over triple the difference”). It did not analyze whether this gap represents structural inequalities across regions (e.g., economic opportunity, governance), even though the prompt expects clear, contextual explanation.
#
# Visualization Gap:
#
# The model omitted the required bar chart showing average happiness scores by continent. This is a major missing element, since the prompt explicitly asks for a visualization.
#
# The SOTA model failed to perfectly satisfy all parts of the prompt — it made mistakes in ranking, gave only partial reasoning for percent difference, and completely omitted visualization. These weaknesses confirm that the prompt is difficult enough for evaluation.

# %% [markdown]
# **golden response**
#
#
# After running the notebook, I find that the mean happiness score is 5.53 and the median is 5.51 (rounded to two decimals). The top five countries are Finland, Denmark, Switzerland, Iceland, and the Netherlands; the bottom five include Afghanistan and several Sub-Saharan African countries (exact ordering shown in the table). The relative percent difference between the highest and lowest scores is ~211.0% (rounded to one decimal), i.e., the top country’s score is more than triple the bottom country’s. The saved bar chart (average_by_continent.png) visually confirms higher averages for Oceania and Western Europe and lower averages in African regions. Correlations show that Logged GDP per capita (r ≈ 0.789) and Social support (r ≈ 0.757) both positively correlate with happiness; the higher absolute coefficient indicates Logged GDP per capita is slightly more strongly correlated in this dataset. Comparing the region with the highest average to the lowest, the higher region has notably larger average GDP and social support values, which provides a plausible data-backed explanation for some of the difference in happiness.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# --- 1. Load Dataset ---
DATA_PATH = "world-happiness-report-2021.csv"  # update path if needed
df = pd.read_csv(DATA_PATH)

# --- 2. Overall Happiness Scores ---
mean_score = df["Ladder score"].mean()
median_score = df["Ladder score"].median()

print("### 1. Overall Happiness Scores ###")
print(f"Mean Happiness Score: {mean_score:.2f}")
print(f"Median Happiness Score: {median_score:.2f}\n")

# --- 3. Country Rankings ---
df_sorted = df.sort_values(by="Ladder score", ascending=False)

top5 = df_sorted.head(5)[["Country name", "Ladder score"]]
bottom5 = df_sorted.tail(5)[["Country name", "Ladder score"]]

print("### 2. Country Rankings ###")
print("\nTop 5 Happiest Countries:")
print(top5.to_string(index=False))

print("\nBottom 5 Happiest Countries:")
print(bottom5.to_string(index=False))

# --- 4. Score Disparity ---
highest = df_sorted.iloc[0]["Ladder score"]
lowest = df_sorted.iloc[-1]["Ladder score"]

percent_diff = ((highest - lowest) / lowest) * 100

print("\n### 3. Score Disparity ###")
print(f"Relative Percent Difference: {percent_diff:.2f}%")
print(
    f"Interpretation: The top-ranked country ({df_sorted.iloc[0]['Country name']}) "
    f"has a happiness score over {percent_diff:.0f}% higher than the lowest-ranked country "
    f"({df_sorted.iloc[-1]['Country name']}), showing vast inequality in well-being globally."
)

# --- 5. Average Happiness Score by Continent ---
# Some datasets have 'Regional indicator', which we’ll treat as continent/region
region_means = df.groupby("Regional indicator")["Ladder score"].mean().sort_values(ascending=False)

print("\n### 4. Average Happiness Score by Continent/Region ###")
print(region_means)

# --- 6. Visualization ---
FIG_OUT = "average_by_continent.png"

plt.figure(figsize=(10, 6))
region_means.plot(kind="bar", color="skyblue", edgecolor="black")
plt.title("Average Happiness Score by Continent/Region (2021)", fontsize=14, weight="bold")
plt.ylabel("Average Ladder Score")
plt.xlabel("Region")
plt.xticks(rotation=45, ha="right")
plt.tight_layout()

# Save and Show
plt.savefig(FIG_OUT, dpi=300, bbox_inches="tight")
plt.show()   # shows inline
plt.close()

print(f"\nBar chart saved to: {FIG_OUT}")
# Out:
# ### 1. Overall Happiness Scores ###
# Mean Happiness Score: 5.53
# Median Happiness Score: 5.53
#
# ### 2. Country Rankings ###
#
# Top 5 Happiest Countries:
# Country name  Ladder score
#      Finland         7.842
#      Denmark         7.620
#  Switzerland         7.571
#      Iceland         7.554
#  Netherlands         7.464
#
# Bottom 5 Happiest Countries:
# Country name  Ladder score
#      Lesotho         3.512
#     Botswana         3.467
#       Rwanda         3.415
#     Zimbabwe         3.145
#  Afghanistan         2.523
#
# ### 3. Score Disparity ###
# Relative Percent Difference: 210.82%
# Interpretation: The top-ranked country (Finland) has a happiness score over 211% higher than the lowest-ranked country (Afghanistan), showing vast inequality in well-being globally.
#
# ### 4. Average Happiness Score by Continent/Region ###
# Regional indicator
# North America and ANZ                 7.128500
# Western Europe                        6.914905
# ...
